# %%
from pathlib import Path

# %%
dest_folder = Path('/Users/cristian/projects/quickshop.ai/qwilo/Template/qwilo-prebuilts/app/images/')

# %%
orig_folder = Path('/Users/cristian/projects/quickshop.ai/landing/app-landing_files')

# %%
_to = [x for x in dest_folder.rglob('*') if x.is_file()]

# %%
_from = [x for x in orig_folder.rglob('*') if x.is_file()]

# %%
orig_folder.rglob('01.png')
# Out:
# <generator object Path.rglob at 0x1053af5e8>

# %%
for x in _to:
     for y in orig_folder.rglob(x.name):
            # !cp {y} {x}

# %%
url = 'https://iqonic.design/themes/qwilo/qwilo-prebuilts/app/images/'

# %%
for x in _to:
    r = x.relative_to(dest_folder)
    # !wget -O {x} {url}{r}
# Out:
# --2019-08-17 22:56:50--  https://iqonic.design/themes/qwilo/qwilo-prebuilts/app/images/favicon.ico
# Resolviendo iqonic.design (iqonic.design)... 2606:4700:30::6818:71d2, 2606:4700:30::6818:70d2, 104.24.112.210, ...
# Conectando con iqonic.design (iqonic.design)[2606:4700:30::6818:71d2]:443... conectado.
# Petici'on HTTP enviada, esperando respuesta... 200 OK
# Longitud: 10806 (11K) [image/vnd.microsoft.icon]
# Grabando a: "/Users/cristian/projects/quickshop.ai/qwilo/Template/qwilo-prebuilts/app/images/favicon.ico"
#
# /Users/cristian/pro 100%[===================>]  10.55K  --.-KB/s    en 0.004s
#
# 2019-08-17 22:56:50 (2.33 MB/s) - "/Users/cristian/projects/quickshop.ai/qwilo/Template/qwilo-prebuilts/app/images/favicon.ico" guardado [10806/10806]
#
# --2019-08-17 22:56:50--  https://iqonic.design/themes/qwilo/qwilo-prebuilts/app/images/loader.gif
# Resolviendo iqonic.design (iqonic.design)... 2606:4700:30::6818:71d2, 2606:4700:30::6818:70d2, 104.24.112.210, ...
# ...
